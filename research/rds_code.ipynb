# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

# %%
# create_engine("mysql+mysqldb://:admin@localhost:3306/datavisualization")
rdsConnection = create_engine("mysql+mysqldb://admin:passwordRDS@visionrds.ch0vw6wkyqa3.ca-central-1.rds.amazonaws.com/video_metadata")

# %%
videoMetadata = pd.read_csv("E:\Study Space\LCIT\Semester 2\AISC2006_Step Presentation\Project\ASLD\Data\metadata.csv")
videoMetadata.head()
# Out:
#    Name     Sign  Length  Size(bytes) Type  FrameRate  Bitrate  Frames  \
# 0   335  abdomen     2.3        82741  MP4  25.000000      285      58
# 1   336  abdomen     2.2       481544  MP4  30.004616     1764      65
# 2   338  abdomen     2.4        72695  MP4  29.970000      242      72
# 3   339  abdomen     2.0        60415  MP4  29.970000      237      61
# 4   341  abdomen     2.8       888854  MP4  30.331450     2568      84
#
#    Resolution
# 0  (320, 240)
# 1  (640, 480)
# 2  (288, 192)
# 3  (288, 192)
# 4  (720, 400)

# %%
# Resetting index as Name
videoMetadata.set_index('Name', inplace=True)

# %%
videoMetadata
# Out:
#           Sign  Length  Size(bytes) Type  FrameRate  Bitrate  Frames  \
# Name
# 335    abdomen     2.3        82741  MP4  25.000000      285      58
# 336    abdomen     2.2       481544  MP4  30.004616     1764      65
# 338    abdomen     2.4        72695  MP4  29.970000      242      72
# 339    abdomen     2.0        60415  MP4  29.970000      237      61
# 341    abdomen     2.8       888854  MP4  30.331450     2568      84
# ...        ...     ...          ...  ...        ...      ...     ...
# 69542     wrap     2.5      3847765  MP4  29.970030    12138      76
# 69544    write     2.8      3171843  MP4  29.970030     9162      83
# 69545   yellow     2.2      2748418  MP4  29.970030    10137      65
# 69546      yes     2.4      3033178  MP4  29.970030    10100      72
# 69547      you     2.2      2684563  MP4  29.970030     9606      67
#
#         Resolution
# Name
# 335     (320, 240)
# 336     (640, 480)
# 338     (288, 192)
# 339     (288, 192)
# 341     (720, 400)
# ...

# %%
# Writing XML data to mysql table
videoMetadata.to_sql(
    name='dataset_analysis', # database table name
    con=rdsConnection,
    if_exists='replace',
    index=True
)
# Out:
# 11046
