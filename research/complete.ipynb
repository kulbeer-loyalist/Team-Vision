# %%
import cv2
import mediapipe as mp
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_holistic = mp.solutions.holistic


# For webcam input:
cap = cv2.VideoCapture(0)
with mp_holistic.Holistic(
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5) as holistic:
  while cap.isOpened():
    success, image = cap.read()
    if not success:
      print("Ignoring empty camera frame.")
      # If loading a video, use 'break' instead of 'continue'.
      continue

    # To improve performance, optionally mark the image as not writeable to
    # pass by reference.
    image.flags.writeable = False
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = holistic.process(image)

    # Draw landmark annotation on the image.
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    
    mp_drawing.draw_landmarks(
        image,
        results.face_landmarks,
        mp_holistic.FACEMESH_CONTOURS,
        landmark_drawing_spec=None,
        connection_drawing_spec=mp_drawing_styles
        .get_default_face_mesh_contours_style())
    
    mp_drawing.draw_landmarks(
        image,
        results.pose_landmarks,
        mp_holistic.POSE_CONNECTIONS,
        landmark_drawing_spec=mp_drawing_styles
        .get_default_pose_landmarks_style())
    
    mp_drawing.draw_landmarks(
            image,
            results.left_hand_landmarks,
            mp_holistic.HAND_CONNECTIONS,
            landmark_drawing_spec=mp_drawing_styles
            .get_default_hand_landmarks_style())
    
    mp_drawing.draw_landmarks(
            image,
            results.right_hand_landmarks,
            mp_holistic.HAND_CONNECTIONS,
            landmark_drawing_spec=mp_drawing_styles
            .get_default_hand_landmarks_style())
    
    # Flip the image horizontally for a selfie-view display.
    cv2.imshow('MediaPipe Holistic', cv2.flip(image, 1))
    if cv2.waitKey(5) & 0xFF == 27:
      break
cap.release()
# Out:
# 2023-08-06 15:20:47.661197: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-06 15:20:48.251838: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
#
# QObject::moveToThread: Current thread (0x7729200) is not the object's thread (0x79389a0).
# Cannot move to target thread (0x7729200)
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132
# Error: index 489 is out of bounds for axis 0 with size 132

# %%
import cv2
import mediapipe as mp
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_holistic = mp.solutions.holistic


# For webcam input:
cap = cv2.VideoCapture(0)
with mp_holistic.Holistic(
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5) as holistic:
  while cap.isOpened():
    success, image = cap.read()
    if not success:
      print("Ignoring empty camera frame.")
      # If loading a video, use 'break' instead of 'continue'.
      continue

    # To improve performance, optionally mark the image as not writeable to
    # pass by reference.
    image.flags.writeable = False
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = holistic.process(image)
    print(results)
    break

    # Draw landmark annotation on the image.
#     image.flags.writeable = True
#     image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    
#     mp_drawing.draw_landmarks(
#         image,
#         results.face_landmarks,
#         mp_holistic.FACEMESH_CONTOURS,
#         landmark_drawing_spec=None,
#         connection_drawing_spec=mp_drawing_styles
#         .get_default_face_mesh_contours_style())
    
#     mp_drawing.draw_landmarks(
#         image,
#         results.pose_landmarks,
#         mp_holistic.POSE_CONNECTIONS,
#         landmark_drawing_spec=mp_drawing_styles
#         .get_default_pose_landmarks_style())
    
#     mp_drawing.draw_landmarks(
#             image,
#             results.left_hand_landmarks,
#             mp_holistic.HAND_CONNECTIONS,
#             landmark_drawing_spec=mp_drawing_styles
#             .get_default_hand_landmarks_style())
    
#     mp_drawing.draw_landmarks(
#             image,
#             results.right_hand_landmarks,
#             mp_holistic.HAND_CONNECTIONS,
#             landmark_drawing_spec=mp_drawing_styles
#             .get_default_hand_landmarks_style())
    
#     # Flip the image horizontally for a selfie-view display.
#     cv2.imshow('MediaPipe Holistic', cv2.flip(image, 1))
#     if cv2.waitKey(5) & 0xFF == 27:
#       break
cap.release()
# Out:
# 2023-08-06 19:46:41.177622: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-06 19:46:41.689908: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
import pandas as pd
pose = pd.DataFrame()
face = pd.DataFrame()
left_hand = pd.DataFrame()
right_hand = pd.DataFrame()
if results.face_landmarks is not None:
    for i, point in enumerate(results.face_landmarks.landmark):
        face.loc[i, ['x','y','z']] = [point.x, point.y, point.z]

if results.pose_landmarks is not None:
    for i, point in enumerate(results.pose_landmarks.landmark):
        pose.loc[i, ['x','y','z']] = [point.x, point.y, point.z]
    

if results.left_hand_landmarks is not None:
    for i, point in enumerate(results.left_hand_landmarks.landmark):
        left_hand.loc[i, ['x','y','z']] = [point.x, point.y, point.z]
    

if results.right_hand_landmarks is not None:
    for i, point in enumerate(results.right_hand_landmarks.landmark):
        right_hand.loc[i, ['x','y','z']] = [point.x, point.y, point.z]

# %%
face
# Out:
#             x         y         z
# 0    0.554755  0.341022 -0.029098
# 1    0.553904  0.298832 -0.041860
# 2    0.554864  0.315114 -0.025242
# 3    0.548269  0.265192 -0.025923
# 4    0.553779  0.286713 -0.043065
# ..        ...       ...       ...
# 463  0.578420  0.247215  0.012584
# 464  0.573337  0.248411  0.007892
# 465  0.570367  0.248520  0.002296
# 466  0.615918  0.244940  0.015621
# 467  0.620860  0.239353  0.016068
#
# [468 rows x 3 columns]

# %% [markdown]
# # create a data frame as a kaggle

# %%
face.plot(x='x',y='y',kind='scatter')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
pose = pd.DataFrame()
face = pd.DataFrame()
left_hand = pd.DataFrame()
right_hand = pd.DataFrame()
if results.face_landmarks is not None:
    for i, point in enumerate(results.face_landmarks.landmark):
        face.loc[i, ['x','y','z']] = [point.x, point.y, point.z]

if results.pose_landmarks is not None:
    for i, point in enumerate(results.pose_landmarks.landmark):
        pose.loc[i, ['x','y','z']] = [point.x, point.y, point.z]
    

if results.left_hand_landmarks is not None:
    for i, point in enumerate(results.left_hand_landmarks.landmark):
        left_hand.loc[i, ['x','y','z']] = [point.x, point.y, point.z]
    

if results.right_hand_landmarks is not None:
    for i, point in enumerate(results.right_hand_landmarks.landmark):
        right_hand.loc[i, ['x','y','z']] = [point.x, point.y, point.z]
        
face = face.reset_index() \
.rename(columns={'index': 'landmark_index'}) \
.assign(type='face')

pose = pose.reset_index() \
.rename(columns={'index': 'landmark_index'}) \
.assign(type='pose')

left_hand = left_hand.reset_index() \
.rename(columns={'index': 'landmark_index'}) \
.assign(type='left_hand')

right_hand = right_hand.reset_index() \
.rename(columns={'index': 'landmark_index'}) \
.assign(type='right_hand')
landmark = pd.concat([face,pose,left_hand,right_hand]).reset_index(drop=True)

# %% [markdown]
# # function of above code

# %%
def create_landmark_frame_df(results,frame,xyz):
    """
    xyz takes the results from mediapipe and creates a dataframe of the landmark
    
    inputs:
        results: mediapipe results object
        frame: frame number
        xyz: dataframe wof the xyz example data
    
    
    """
    
    #we want the values and rows for every type landmark index so we need skeleton
    xyz_skel = xyz[['type','landmark_index']].drop_duplicates() \
    .reset_index(drop=True).copy()
    
    pose = pd.DataFrame()
    face = pd.DataFrame()
    left_hand = pd.DataFrame()
    right_hand = pd.DataFrame()
    
    if results.face_landmarks is not None:
        for i, point in enumerate(results.face_landmarks.landmark):
            face.loc[i, ['x','y','z']] = [point.x, point.y, point.z]

    if results.pose_landmarks is not None:
        for i, point in enumerate(results.pose_landmarks.landmark):
            pose.loc[i, ['x','y','z']] = [point.x, point.y, point.z]


    if results.left_hand_landmarks is not None:
        for i, point in enumerate(results.left_hand_landmarks.landmark):
            left_hand.loc[i, ['x','y','z']] = [point.x, point.y, point.z]


    if results.right_hand_landmarks is not None:
        for i, point in enumerate(results.right_hand_landmarks.landmark):
            right_hand.loc[i, ['x','y','z']] = [point.x, point.y, point.z]

    face = face.reset_index() \
    .rename(columns={'index': 'landmark_index'}) \
    .assign(type='face')

    pose = pose.reset_index() \
    .rename(columns={'index': 'landmark_index'}) \
    .assign(type='pose')

    left_hand = left_hand.reset_index() \
    .rename(columns={'index': 'landmark_index'}) \
    .assign(type='left_hand')

    right_hand = right_hand.reset_index() \
    .rename(columns={'index': 'landmark_index'}) \
    .assign(type='right_hand')

    landmark = pd.concat([face,pose,left_hand,right_hand]).reset_index(drop=True)
    #merge with lanndmark
    landmark = xyz_skel.merge(landmark, on=['type','landmark_index'], how='left')
    #assign frames to make it unique
    landmark = landmark.assign(frame = frame)
    return landmark

# %% [raw]
# pose.shape

# %%
left_hand.shape
# Out:
# (21, 5)

# %%
right_hand.shape
# Out:
# (21, 5)

# %%
face.shape
# Out:
# (468, 6)

# %%
landmark
# Out:
#     landmark_index         x         y         z  type
# 0                0  0.550014  0.789942 -0.033678  face
# 1                1  0.546171  0.726674 -0.071497  face
# 2                2  0.549527  0.744343 -0.036053  face
# 3                3  0.535409  0.658788 -0.055268  face
# 4                4  0.545219  0.706012 -0.077011  face
# ..             ...       ...       ...       ...   ...
# 496             28  0.322477  3.360964  0.714034  pose
# 497             29  0.656874  3.517106  0.924152  pose
# 498             30  0.316177  3.478506  0.754359  pose
# 499             31  0.573891  3.638295  0.087590  pose
# 500             32  0.377465  3.615012 -0.136146  pose
#
# [501 rows x 5 columns]

# %%
xyz_skel = xyz[['type','landmark_index']].drop_duplicates() \
    .reset_index(drop=True).copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 xyz_skel = xyz[['type','landmark_index']].drop_duplicates() \
#       2     .reset_index(drop=True).copy()
#
# NameError: name 'xyz' is not defined

# %% [markdown]
# we want the values and rows for every type landmark index so we need skeleton

# %%
#merge with lanndmark
xyz_skel.merge(landmark, on=['type','landmark_index'], how='left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 #merge with lanndmark
# ----> 2 xyz_skel.merge(landmark, on=['type','landmark_index'], how='left')
#
# NameError: name 'xyz_skel' is not defined

# %%
create_landmark_frame_df(results,frame=0)
# Out:
#            type  landmark_index         x         y         z  frame
# 0          face               0  0.554755  0.341022 -0.029098      0
# 1          face               1  0.553904  0.298832 -0.041860      0
# 2          face               2  0.554864  0.315114 -0.025242      0
# 3          face               3  0.548269  0.265192 -0.025923      0
# 4          face               4  0.553779  0.286713 -0.043065      0
# ..          ...             ...       ...       ...       ...    ...
# 538  right_hand              16  0.299987  0.273202 -0.048380      0
# 539  right_hand              17  0.272188  0.462499 -0.025153      0
# 540  right_hand              18  0.255823  0.406399 -0.037925      0
# 541  right_hand              19  0.246540  0.366211 -0.044848      0
# 542  right_hand              20  0.240174  0.327363 -0.049727      0
#
# [543 rows x 6 columns]

# %%
train['sign'].value_counts()
# Out:
# listen    415
# look      414
# shhh      411
# donkey    410
# mouse     408
#          ...
# dance     312
# person    312
# beside    310
# vacuum    307
# zipper    299
# Name: sign, Length: 250, dtype: int64

# %%
import pandas as pd
import numpy as np
ROWS_PER_FRAME = 543

def load_relevent_data_subset(pq_path):
    data_columns = ['x','y','z']
    data = pd.read_parquet(pq_path,columns=data_columns)
    n_frames = int(len(data) / ROWS_PER_FRAME)
    data = data.values.reshape(n_frames, ROWS_PER_FRAME,len(data_columns))
    return data.astype(np.float32)




import cv2
import pandas as pd
import mediapipe as mp
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_holistic = mp.solutions.holistic

def create_landmark_frame_df(results,frame,xyz):
    """
    xyz takes the results from mediapipe and creates a dataframe of the landmark
    
    inputs:
        results: mediapipe results object
        frame: frame number
        xyz: dataframe wof the xyz example data
    
    
    """
    
    #we want the values and rows for every type landmark index so we need skeleton
    xyz_skel = xyz[['type','landmark_index']].drop_duplicates() \
    .reset_index(drop=True).copy()
    
    pose = pd.DataFrame()
    face = pd.DataFrame()
    left_hand = pd.DataFrame()
    right_hand = pd.DataFrame()
    
    if results.face_landmarks is not None:
        for i, point in enumerate(results.face_landmarks.landmark):
            face.loc[i, ['x','y','z']] = [point.x, point.y, point.z]

    if results.pose_landmarks is not None:
        for i, point in enumerate(results.pose_landmarks.landmark):
            pose.loc[i, ['x','y','z']] = [point.x, point.y, point.z]


    if results.left_hand_landmarks is not None:
        for i, point in enumerate(results.left_hand_landmarks.landmark):
            left_hand.loc[i, ['x','y','z']] = [point.x, point.y, point.z]


    if results.right_hand_landmarks is not None:
        for i, point in enumerate(results.right_hand_landmarks.landmark):
            right_hand.loc[i, ['x','y','z']] = [point.x, point.y, point.z]

    face = face.reset_index() \
    .rename(columns={'index': 'landmark_index'}) \
    .assign(type='face')

    pose = pose.reset_index() \
    .rename(columns={'index': 'landmark_index'}) \
    .assign(type='pose')

    left_hand = left_hand.reset_index() \
    .rename(columns={'index': 'landmark_index'}) \
    .assign(type='left_hand')

    right_hand = right_hand.reset_index() \
    .rename(columns={'index': 'landmark_index'}) \
    .assign(type='right_hand')

    landmark = pd.concat([face,pose,left_hand,right_hand]).reset_index(drop=True)
    #merge with lanndmark
    landmark = xyz_skel.merge(landmark, on=['type','landmark_index'], how='left')
    #assign frames to make it unique
    landmark = landmark.assign(frame = frame)
    return landmark

def do_capture_web(xyz):
    landmarks_all = []

    cap = cv2.VideoCapture(0)
    with mp_holistic.Holistic(min_detection_confidence=0.5,min_tracking_confidence=0.5) as holistic:
        frame = 0  
        while cap.isOpened():
                #take frame and increment it
            frame+=1
            success, image = cap.read()
            if not success:
                print("Ignoring empty camera frame.")
                    # If loading a video, use 'break' instead of 'continue'.
                continue

                # To improve performance, optionally mark the image as not writeable to
                # pass by reference.
            image.flags.writeable = False
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            results = holistic.process(image)
            #create landmark dataframe
            landmark = create_landmark_frame_df(results, frame, xyz)
            landmarks_all.append(landmark)
            

            # Draw landmark annotation on the image.
            image.flags.writeable = True
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            mp_drawing.draw_landmarks(
                image,
                results.face_landmarks,
                mp_holistic.FACEMESH_CONTOURS,
                landmark_drawing_spec=None,
                connection_drawing_spec=mp_drawing_styles
                .get_default_face_mesh_contours_style())

            mp_drawing.draw_landmarks(
                image,
                results.pose_landmarks,
                mp_holistic.POSE_CONNECTIONS,
                landmark_drawing_spec=mp_drawing_styles
                .get_default_pose_landmarks_style())

            mp_drawing.draw_landmarks(
                image,
                results.left_hand_landmarks,
                mp_holistic.HAND_CONNECTIONS,
                landmark_drawing_spec=mp_drawing_styles
                .get_default_hand_landmarks_style())

            mp_drawing.draw_landmarks(
                image,
                results.right_hand_landmarks,
                mp_holistic.HAND_CONNECTIONS,
                landmark_drawing_spec=mp_drawing_styles
                .get_default_hand_landmarks_style())
            
            landmark = pd.concat(landmarks_all).reset_index(drop=True)
            

                # Flip the image horizontally for a selfie-view display.
            cv2.imshow('MediaPipe Holistic', cv2.flip(image, 1))
            if cv2.waitKey(5) & 0xFF == 27:
                break
                
    
    return landmarks_all    

if __name__ == "__main__":
    xyz = pd.read_parquet('./2044/635217.parquet')
    landmark = do_capture_web(xyz)
    landmark = pd.concat(landmark).reset_index(drop=True) \
    .to_paruqet('output1.parquet')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 157
#     154 xyz = pd.read_parquet('./2044/635217.parquet')
#     155 landmark = do_capture_web(xyz)
#     156 landmark = pd.concat(landmark).reset_index(drop=True) \
# --> 157 .to_paruqet('output1.parquet')
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_paruqet'

# %%
# !ls
# Out:
# /bin/bash: /home/lang_chain/anaconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# 2044  complete.ipynb  inference.ipynb  model.tflite  Team-Vision  train.csv
